# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json, lxml
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
# import folium # map rendering library
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
try:
    import folium
except:
    # !pip install folium
    import folium

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text
soup = BeautifulSoup(source)

table_data = soup.find('div', class_='mw-parser-output')
table = table_data.table.tbody

columns = ['PostalCode', 'Borough', 'Neighbourhood']
data = dict({key:[]*len(columns) for key in columns})

for row in table.find_all('tr'):
    for i,column in zip(row.find_all('td'),columns):
        i = i.text
        i = i.replace('\n', '')
        data[column].append(i)

df = pd.DataFrame.from_dict(data=data)[columns]
print(df.shape)
df.head()
# Out:
# (20, 3)
#                                           PostalCode          Borough  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                     Neighbourhood
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned

# %%
df = df[df['Borough'] != 'Not assigned'].reset_index(drop = True)
print('After dropping rows where borough is "Not assigned", Shape is: ',df.shape)
print('Number of rows where Neighbourhood is "Not assigned" but borough has value: ', 
      df[df['Neighbourhood'] == 'Not assigned'].shape[0])
# Out:
# After dropping rows where borough is "Not assigned", Shape is:  (20, 3)
# Number of rows where Neighbourhood is "Not assigned" but borough has value:  0

# %%
p, b, n = [], [], []
for postcode, borough, neigh in zip(df['PostalCode'], df['Borough'], df['Neighbourhood']):
    p.append(postcode)
    b.append(borough)
    if neigh == 'Not assigned':
        n.append(borough)
    else:
        n.append(neigh)

df = pd.DataFrame({'PostalCode': p, 'Borough': b, 'Neighbourhood':n})[columns]
print(df.shape)
df.head()
# Out:
# (20, 3)
#                                           PostalCode          Borough  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                     Neighbourhood
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned

# %%
postcodes = df['PostalCode'].values
boroughs = df['Borough'].values
neighs = df['Neighbourhood'].values

#create a dictionary with keys as Postcode and Borough, keys of dictioaries are unique
dic = dict({(key1,key2): [] for key1, key2 in zip(postcodes, boroughs)})
print('Number of keys in the dictionary are: ', len(dic.keys()))

#filling the values of keys of dictionary
for postcode, borough, neigh in zip(postcodes,boroughs, neighs):
    key = (postcode, borough)
    dic[key].append(neigh)

df = pd.DataFrame(columns = ['Postal Code', 'Borough', 'Neighbourhood'])
for key, value in dic.items():
    postcode, borough, neig = key[0], key[1], value
    neig = ', '.join(neig)
    df = df.append({'Postal Code': postcode,
                     'Borough': borough,
                     'Neighbourhood': neig}, ignore_index = True)
print('Shape of final data is: ', df.shape)
df.head(10)
# Out:
# Number of keys in the dictionary are:  20
# Shape of final data is:  (20, 3)
#                                          Postal Code  \
# 0                                    M1ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...
# 3  M1EScarborough(Guildwood / Morningside / West ...
# 4                             M1GScarborough(Woburn)
# 5                          M1HScarborough(Cedarbrae)
# 6                M1JScarborough(Scarborough Village)
# 7  M1KScarborough(Kennedy Park / Ionview / East B...
# 8  M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9  M1MScarborough(Cliffside / Cliffcrest / Scarbo...
#
#                                          Borough  \
# 0                                M2ANot assigned
# 1                                M2BNot assigned
# 2                                M2CNot assigned
# 3                                M2ENot assigned
# 4                                M2GNot assigned
# 5               M2HNorth York(Hillcrest Village)
# 6  M2JNorth York(Fairview / Henry Farm / Oriole)
# 7                 M2KNorth York(Bayview Village)
# 8       M2LNorth York(York Mills / Silver Hills)
# 9        M2MNorth York(Willowdale / Newtonbrook)
#
#                                        Neighbourhood
# 0                           M3ANorth York(Parkwoods)
# 1                      M3BNorth York(Don Mills)North
# 2     M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                    M3ENot assigned
# 4                                    M3GNot assigned
# 5  M3HNorth York(Bathurst Manor / Wilson Heights ...
# 6    M3JNorth York(Northwood Park / York University)
# 7        M3KNorth York(Downsview)East  (CFB Toronto)
# 8                       M3LNorth York(Downsview)West
# 9                    M3MNorth York(Downsview)Central

# %%
# import geocoder # import geocoder
# lats, lons = [], []
# count = 0
# for postal_code in df['PostalCode'].values:
#     # initialize your variable to None
#     lat_lng_coords = None
#     # loop until you get the coordinates
#     while(lat_lng_coords is None):
#         g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#         lat_lng_coords = g.latlng
#         lats.append(lat_lng_coords[0])
#         lons.append(lat_lng_coords[1])

# %%
# download the data of latitude and longitude: link provided by >>>>coursera
# !wget http://cocl.us/Geospatial_data
try:
    df['Latitude'] = lats
    df['Longitude'] = lons
except:
    latlon = pd.read_csv('Geospatial_data')
    df = pd.merge(df, latlon, how= 'inner', on = 'Postal Code')
    
print(df.shape)
df.head(10)
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2021-07-01 13:20:22--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 52.116.122.240, 52.116.127.25
# Connecting to cocl.us (cocl.us)|52.116.122.240|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-07-01 13:20:23--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 185.235.236.197
# Connecting to ibm.box.com (ibm.box.com)|185.235.236.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-07-01 13:20:24--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-07-01 13:20:24--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 185.235.236.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|185.235.236.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!q8h6XVxMebMYxqaiXEvZvmyNLvR-tYr1UIMXF96ghE7GKDuTsXPkZH4-Mwuxofa05pXhcGZStrGOhzUdqP1AjhgL_ou_mYOeVujSdcmek3sq8O29rkZDxmDGJtBvR6GSpBO6JoaJ-gsoHcCaL8_WBc3uvwsHFDeTVTmB5oKg30ruNaBAcyx7Io_1PjgHqVQHPapjsNdpAl8DLjvhjAN8nG2hZ1tZy1f2xLBH-PgJA-cq5yd7yKJRlV3zvVMcIvWfXmezp6H6BvsE1i0DVKqVwNQApDu_bl28mWW4mlDM6-IE56M5HaY-F8ylbBgo0kEq_ks7pT77p_MiT_E1D9pNFzwmZbgOSXjWGWofqKuqoP4cv2xDqEPwQOKIGf7DzVi4YbWL0yit49PCwblnTMvKfea_NVuaRdEyMVMjZzAHfEItwd9zuXcxp1LOUdpnpb-GXw_RtizX-o70ZuFSxN5mUGdHxTCIRl29PfO26TPjRko5-g-jceB-peIddPqjK2vUksCFHWBT564eQg_TDxiG0xYNri1ZCuqvCVlLkklcO3gdW_hPYjVUjzPZiBXfRSq7BXcX-sQX47J9lKogGhGP3Gz_qrqiNHjuBFGO9jImA8kdbfSVQdiSsXS2uGLX4Qi3tXDdUTGr2ZHPR8b7tv7N_4TfJYlCy947MU52qIqbxd2CLIgd4gd94ZTHqsad0AQgzhXfRGZC4fq1O2QkXdvD4KOTdXYaKb_OYElySkhkwEDBTqU-tUlhWD0uAv82pv5Lbx0kNRCCOeXZhH03y-f0Gv5tUIXx68bxssYG2DNQ1Nd0SlNNPxyBc28JHLtrc7vMectgnnAAvg22hxbgNZpmrrHNT61S9vTKFFadsTFxYtuiNI7eOjJMKXIKCAQRI1ItnHw47HJZpjMdFqCfH_0YIIlI6CFnbeKM6mpumDQMHCy4t_UWPW80gwumGA6LGk9cYAo-ZrgufIWEsOr_7U2nYgSybP2sBXHp59aXfBkOiv69PJ56-SublNI6VspcBFwwa0iTh-RJ9ImOAscevajxtEKYjDOLTLPDqdyKZGsMmf4pRmCKgKyobHlWMsr3BVVYYOVCzAcqDU33-sP-7Ov8fklSeimejqzbEY2WnA2tC-6Dblhm2XxinmUmrvTXI2h5vL5GuHwqe8kWIgzOMIwbLq83dXCY2KCbmIYcaJ1ZJOkT-hsoufvfLf8wIGTJ6ZmeSgUEI5m4nGlAdIG0U0a1Dxlm22S_-pnYjP-1bOx2RBea94dPOuTYAImi_8qOPrKGWLt9bqltC6kcWofrI9TX3698ChF8cW6ylqfOxWw_OfSw_7-F0UvLF8V-CGqiGfKqaJzD4RVo9pNxgc9WhVaUydfYVhugFRnmj4mXJuTVil8IM13kaeVX5fxzXKBVnpkr0Vc2vnVi0Xsdju2pttlMVzC4MblKyx7MrGnhVPOXqsGOuVc./download [following]
# --2021-07-01 13:20:25--  https://public.boxcloud.com/d/1/b1!q8h6XVxMebMYxqaiXEvZvmyNLvR-tYr1UIMXF96ghE7GKDuTsXPkZH4-Mwuxofa05pXhcGZStrGOhzUdqP1AjhgL_ou_mYOeVujSdcmek3sq8O29rkZDxmDGJtBvR6GSpBO6JoaJ-gsoHcCaL8_WBc3uvwsHFDeTVTmB5oKg30ruNaBAcyx7Io_1PjgHqVQHPapjsNdpAl8DLjvhjAN8nG2hZ1tZy1f2xLBH-PgJA-cq5yd7yKJRlV3zvVMcIvWfXmezp6H6BvsE1i0DVKqVwNQApDu_bl28mWW4mlDM6-IE56M5HaY-F8ylbBgo0kEq_ks7pT77p_MiT_E1D9pNFzwmZbgOSXjWGWofqKuqoP4cv2xDqEPwQOKIGf7DzVi4YbWL0yit49PCwblnTMvKfea_NVuaRdEyMVMjZzAHfEItwd9zuXcxp1LOUdpnpb-GXw_RtizX-o70ZuFSxN5mUGdHxTCIRl29PfO26TPjRko5-g-jceB-peIddPqjK2vUksCFHWBT564eQg_TDxiG0xYNri1ZCuqvCVlLkklcO3gdW_hPYjVUjzPZiBXfRSq7BXcX-sQX47J9lKogGhGP3Gz_qrqiNHjuBFGO9jImA8kdbfSVQdiSsXS2uGLX4Qi3tXDdUTGr2ZHPR8b7tv7N_4TfJYlCy947MU52qIqbxd2CLIgd4gd94ZTHqsad0AQgzhXfRGZC4fq1O2QkXdvD4KOTdXYaKb_OYElySkhkwEDBTqU-tUlhWD0uAv82pv5Lbx0kNRCCOeXZhH03y-f0Gv5tUIXx68bxssYG2DNQ1Nd0SlNNPxyBc28JHLtrc7vMectgnnAAvg22hxbgNZpmrrHNT61S9vTKFFadsTFxYtuiNI7eOjJMKXIKCAQRI1ItnHw47HJZpjMdFqCfH_0YIIlI6CFnbeKM6mpumDQMHCy4t_UWPW80gwumGA6LGk9cYAo-ZrgufIWEsOr_7U2nYgSybP2sBXHp59aXfBkOiv69PJ56-SublNI6VspcBFwwa0iTh-RJ9ImOAscevajxtEKYjDOLTLPDqdyKZGsMmf4pRmCKgKyobHlWMsr3BVVYYOVCzAcqDU33-sP-7Ov8fklSeimejqzbEY2WnA2tC-6Dblhm2XxinmUmrvTXI2h5vL5GuHwqe8kWIgzOMIwbLq83dXCY2KCbmIYcaJ1ZJOkT-hsoufvfLf8wIGTJ6ZmeSgUEI5m4nGlAdIG0U0a1Dxlm22S_-pnYjP-1bOx2RBea94dPOuTYAImi_8qOPrKGWLt9bqltC6kcWofrI9TX3698ChF8cW6ylqfOxWw_OfSw_7-F0UvLF8V-CGqiGfKqaJzD4RVo9pNxgc9WhVaUydfYVhugFRnmj4mXJuTVil8IM13kaeVX5fxzXKBVnpkr0Vc2vnVi0Xsdju2pttlMVzC4MblKyx7MrGnhVPOXqsGOuVc./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.29.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.29.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.2’
#
# Geospatial_data.2   100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2021-07-01 13:20:25 (37.9 MB/s) - ‘Geospatial_data.2’ saved [2891/2891]
#
# (0, 7)
# Empty DataFrame
# Columns: [Borough, Neighbourhood, Latitude_x, Longitude_x, Postal Code, Latitude_y, Longitude_y]
# Index: []
